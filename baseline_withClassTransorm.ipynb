# %% [markdown]
# # First attempt

# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklift.models import ClassTransformation
from sklift import metrics
from sklift import viz

# %%
clients = pd.read_csv('clients2_modified.csv', index_col='client_id')
clients
# Out:
#             first_issue_date  first_redeem_date   age  gender_F  gender_M  \
# client_id
# 000012768d             17383              17535  45.0         0         0
# 000036f903             17266              17279  72.0         1         0
# 00010925a5             17736              17788  83.0         0         0
# 0001f552b0             17347              17771  33.0         1         0
# 00020e7b18             17497              17541  73.0         0         0
# ...                      ...                ...   ...       ...       ...
# fffe0abb97             17497              17573  35.0         1         0
# fffe0ed719             17424              17512  69.0         0         0
# fffea1204c             17562              17602  73.0         1         0
# fffeca6d22             17528              18220  77.0         1         0
# fffff6ce77             17381              17404  42.0         0         0
#
#             no_redeem
# client_id
# 000012768d          0
# 000036f903          0
# 00010925a5          0
# 0001f552b0          0
# 00020e7b18          0
# ...               ...
# fffe0abb97          0
# fffe0ed719          0
# fffea1204c          0
# fffeca6d22          1
# fffff6ce77          0
#
# [200039 rows x 6 columns]

# %%
x_cols = clients.columns

# %%
df_full = pd.read_csv('train.csv', index_col='client_id')\
    .join(clients, how='left')
df_full
# Out:
#             treatment_flg  purchased  first_issue_date  first_redeem_date  \
# client_id
# ad6561e2d8              1          1             17503              17674
# 7c1ccbf93f              1          1             17480              17584
# b58fadcab6              1          1             17472              17789
# e99e6fabb9              0          0             17667              17681
# 27fb6f8520              1          1             17364              17515
# ...                   ...        ...               ...                ...
# 999d284453              1          1             17835              17992
# f634deea4e              0          1             17566              17602
# 16cb4f99b0              0          1             17585              18047
# 23c2b72b2e              1          1             17348              17457
# 1430184499              0          1             17308              17589
#
#              age  gender_F  gender_M  no_redeem
# client_id
# ad6561e2d8  50.0         1         0          0
# 7c1ccbf93f  24.0         1         0          0
# b58fadcab6  36.0         0         0          0
# e99e6fabb9  79.0         1         0          0
# 27fb6f8520  34.0         1         0          0
# ...          ...       ...       ...        ...
# 999d284453  72.0         0         0          0
# f634deea4e  35.0         0         0          0
# 16cb4f99b0  50.0         1         0          0
# 23c2b72b2e  55.0         0         0          0
# 1430184499  63.0         0         1          0
#
# [140027 rows x 8 columns]

# %%
indices_train, indices_val = train_test_split(df_full.index, 
                                              test_size=0.2, 
                                              random_state=8)

# %%
indices_train.shape
# Out:
# (112021,)

# %%
indices_val.shape
# Out:
# (28006,)

# %%
X_train = df_full.loc[indices_train, x_cols]
X_train
# Out:
#             first_issue_date  first_redeem_date   age  gender_F  gender_M  \
# client_id
# fd1ab717e8             17774              17977  69.0         1         0
# 5be3f83065             17918              18036  67.0         1         0
# 1c48fc99b2             17319              17359  58.0         1         0
# fcce9d3197             17370              17387  43.0         0         0
# 4f43f48cb7             17385              17842  42.0         0         0
# ...                      ...                ...   ...       ...       ...
# c5792264c8             17424              17548  66.0         0         0
# 84880145bd             17895              17929  35.0         0         1
# 49eb365a88             17323              17566  20.0         0         1
# 1b55a9f080             17377              17955  47.0         0         0
# 9961481e46             17565              17691  69.0         1         0
#
#             no_redeem
# client_id
# fd1ab717e8          0
# 5be3f83065          0
# 1c48fc99b2          0
# fcce9d3197          0
# 4f43f48cb7          0
# ...               ...
# c5792264c8          0
# 84880145bd          0
# 49eb365a88          0
# 1b55a9f080          0
# 9961481e46          0
#
# [112021 rows x 6 columns]

# %%
treat_train = df_full.loc[indices_train, 'treatment_flg']
treat_train
# Out:
# client_id
# fd1ab717e8    1
# 5be3f83065    1
# 1c48fc99b2    0
# fcce9d3197    1
# 4f43f48cb7    0
#              ..
# c5792264c8    0
# 84880145bd    0
# 49eb365a88    0
# 1b55a9f080    1
# 9961481e46    1
# Name: treatment_flg, Length: 112021, dtype: int64

# %%
y_train = df_full.loc[indices_train, 'purchased']
y_train
# Out:
# client_id
# fd1ab717e8    1
# 5be3f83065    0
# 1c48fc99b2    1
# fcce9d3197    1
# 4f43f48cb7    1
#              ..
# c5792264c8    1
# 84880145bd    1
# 49eb365a88    0
# 1b55a9f080    0
# 9961481e46    1
# Name: purchased, Length: 112021, dtype: int64

# %%
X_val = df_full.loc[indices_val, x_cols]
X_val
# Out:
#             first_issue_date  first_redeem_date   age  gender_F  gender_M  \
# client_id
# c0582c1d5e             17570              17748  56.0         0         0
# 9a96a00f1d             17369              17482  64.0         1         0
# 55bca71943             17641              18220  32.0         0         0
# 5bb5a27171             17353              17426  41.0         1         0
# d9c7b97fba             17323              17933  42.0         0         1
# ...                      ...                ...   ...       ...       ...
# f68c84f07b             17847              18220  19.0         0         1
# 704cff2628             17529              17643  42.0         0         0
# feff930002             17371              17583  29.0         1         0
# fa31a8a3bb             17965              18220  49.0         0         0
# cf760d447c             17538              17610  31.0         0         0
#
#             no_redeem
# client_id
# c0582c1d5e          0
# 9a96a00f1d          0
# 55bca71943          1
# 5bb5a27171          0
# d9c7b97fba          0
# ...               ...
# f68c84f07b          1
# 704cff2628          0
# feff930002          0
# fa31a8a3bb          1
# cf760d447c          0
#
# [28006 rows x 6 columns]

# %%
treat_val = df_full.loc[indices_val, 'treatment_flg']
treat_val
# Out:
# client_id
# c0582c1d5e    1
# 9a96a00f1d    0
# 55bca71943    0
# 5bb5a27171    0
# d9c7b97fba    0
#              ..
# f68c84f07b    0
# 704cff2628    1
# feff930002    1
# fa31a8a3bb    0
# cf760d447c    1
# Name: treatment_flg, Length: 28006, dtype: int64

# %%
y_val = df_full.loc[indices_val, 'purchased']
y_val
# Out:
# client_id
# c0582c1d5e    1
# 9a96a00f1d    1
# 55bca71943    0
# 5bb5a27171    1
# d9c7b97fba    0
#              ..
# f68c84f07b    1
# 704cff2628    1
# feff930002    1
# fa31a8a3bb    0
# cf760d447c    1
# Name: purchased, Length: 28006, dtype: int64

# %% [markdown]
# # Model

# %%
ct = ClassTransformation(XGBClassifier(random_state=8))

# %%
# %%time
ct = ct.fit(X_train, y_train, treat_train)
# Out:
# /home/denis/MyCode/Git/Kaggle_CFT/env/lib/python3.10/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/denis/MyCode/Git/Kaggle_CFT/env/lib/python3.10/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [15:29:17] WARNING: /tmp/abs_40obctay9q/croots/recipe/xgboost-split_1659548945886/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# CPU times: user 7.01 s, sys: 99.3 ms, total: 7.11 s
# Wall time: 1.89 s

# %% [markdown]
# # Checking on the validation set

# %%
y_pred_val = ct.predict(X_val)
y_pred_val
# Out:
# array([ 0.03850555,  0.20317423,  0.00377274, ..., -0.00095135,
#        -0.1429637 , -0.25447196], dtype=float32)

# %%
viz.plot_qini_curve(y_val, y_pred_val, treat_val);

# %%
y_pred_train = ct.predict(X_train)
y_pred_train
# Out:
# array([ 0.6718917 , -0.08005166,  0.07349193, ...,  0.13551402,
#        -0.0190627 ,  0.05566263], dtype=float32)

# %%
viz.plot_qini_curve(y_train, y_pred_train, treat_train);

# %%
metrics.qini_auc_score(y_val, y_pred_val, treat_val)
# Out:
# 0.006797513219712619

# %%
metrics.qini_auc_score(y_train, y_pred_train, treat_train)
# Out:
# 0.1891896848333636

# %% [markdown]
# # Prediction on the test set

# %%
X_test = pd.read_csv('test.csv', index_col='client_id')\
    .join(clients, how='left')
X_test
# Out:
#             first_issue_date  first_redeem_date        age  gender_F  \
# client_id
# a9a604ed6e             17787              18220  36.000000         1
# ebd7360016             17350              17410  63.000000         1
# 908cd9b8e8             17620              17725  49.000000         1
# dceb8ce861             17445              17754  46.000000         0
# f4f0ac6b06             17709              17942  46.379533         0
# ...                      ...                ...        ...       ...
# 4762fb04c5             17682              17891  26.000000         0
# 533d1516e7             17438              17538  37.000000         0
# c93b21a707             17807              17985  42.000000         0
# 3fe0668de5             17890              17929  33.000000         0
# 8d1ea24f5e             17318              17968  32.000000         1
#
#             gender_M  no_redeem
# client_id
# a9a604ed6e         0          1
# ebd7360016         0          0
# 908cd9b8e8         0          0
# dceb8ce861         0          0
# f4f0ac6b06         0          0
# ...              ...        ...
# 4762fb04c5         1          0
# 533d1516e7         1          0
# c93b21a707         0          0
# 3fe0668de5         0          0
# 8d1ea24f5e         0          0
#
# [60012 rows x 6 columns]

# %%
y_pred_test = ct.predict(X_test); y_pred_test
# Out:
# array([-0.09182489,  0.14384079,  0.0584265 , ..., -0.18592596,
#         0.07310808,  0.04659224], dtype=float32)

# %%
X_test['pred'] = y_pred_test
X_test
# Out:
#             first_issue_date  first_redeem_date        age  gender_F  \
# client_id
# a9a604ed6e             17787              18220  36.000000         1
# ebd7360016             17350              17410  63.000000         1
# 908cd9b8e8             17620              17725  49.000000         1
# dceb8ce861             17445              17754  46.000000         0
# f4f0ac6b06             17709              17942  46.379533         0
# ...                      ...                ...        ...       ...
# 4762fb04c5             17682              17891  26.000000         0
# 533d1516e7             17438              17538  37.000000         0
# c93b21a707             17807              17985  42.000000         0
# 3fe0668de5             17890              17929  33.000000         0
# 8d1ea24f5e             17318              17968  32.000000         1
#
#             gender_M  no_redeem      pred
# client_id
# a9a604ed6e         0          1 -0.091825
# ebd7360016         0          0  0.143841
# 908cd9b8e8         0          0  0.058426
# dceb8ce861         0          0  0.126195
# f4f0ac6b06         0          0  0.069185
# ...              ...        ...       ...
# 4762fb04c5         1          0  0.110146
# 533d1516e7         1          0  0.005772
# c93b21a707         0          0 -0.185926
# 3fe0668de5         0          0  0.073108
# 8d1ea24f5e         0          0  0.046592
#
# [60012 rows x 7 columns]

# %%
X_test.pred.to_csv('submit_baseline_ct.csv')

# %% [markdown]
# # Feature importance

# %%
pd.DataFrame({'value':ct.estimator.get_booster().get_score(importance_type='gain')})
# Out:
#                       value
# age                2.624228
# first_issue_date   2.790446
# first_redeem_date  4.061782
# gender_F           2.303584
# gender_M           2.440533
